# %% [markdown]
# <a href="https://colab.research.google.com/github/yeji79/BioBigData/blob/main/bio_bigdata_workshop_1A_python_pandas_visualization_practice_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 바이오 빅데이터 분석 (1A): Python/Pandas Bridge + Visualization Practice
#
# ### 이 노트북의 목적
# 이 노트북은 파이썬 기초 문법을 한 번 배운 수강생이 실제 바이오 빅데이터 분석 코드로 넘어가기 위한 실습 자료입니다.
# 문법 자체를 길게 반복하기보다는, 생명과학/의학 데이터 분석에서 자주 쓰는 `pandas DataFrame`과 기본 시각화 흐름을 실제 데이터로 연습합니다.
#
# ### 실습 주제
# 1. 바이오 데이터 테이블 구조 이해와 pandas DataFrame 핵심 복습
# 2. TCGA-BRCA 유방암 데이터의 gene expression과 clinical metadata 다루기
# 3. DataFrame 선택, 조건 필터링, `groupby`, table 결합 연습
# 4. 데이터 분포 시각화: histogram, pairplot, boxplot, violin plot, heatmap
#
# ### 사용할 데이터
# 1. CancerSEEK data: 단백질 marker와 임상 정보
# 2. TCGA-BRCA cohort: 유방암 gene expression과 clinical subtype
# 3. CCLE-CTRPv2: 암세포주 gene expression과 약물 반응 AUC
#
# #### Machine Learning and Bioinformatics (MLBI) Lab

# %% [markdown]
# ## 0. 필요한 패키지 설치 (처음 한번만 하면 됨)

# %%
# 수업 환경에서 mlbi-lab 또는 scikit-network가 없을 때만 주석을 해제하고 실행하세요. (클러스터링, 통계검정 할 때 쓸 패키지)
# !pip install mlbi-lab scikit-network statannotations
# Out:
# Requirement already satisfied: mlbi-lab in /usr/local/lib/python3.12/dist-packages (0.5.3)
# Requirement already satisfied: scikit-network in /usr/local/lib/python3.12/dist-packages (0.33.5)
# Requirement already satisfied: statannotations in /usr/local/lib/python3.12/dist-packages (0.7.2)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from mlbi-lab) (5.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mlbi-lab) (2.5.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from mlbi-lab) (2.3.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mlbi-lab) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from mlbi-lab) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mlbi-lab) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from mlbi-lab) (0.13.2)
# Requirement already satisfied: anndata in /usr/local/lib/python3.12/dist-packages (from mlbi-lab) (0.13.1)
# Requirement already satisfied: lifelines in /usr/local/lib/python3.12/dist-packages (from mlbi-lab) (0.30.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mlbi-lab) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mlbi-lab) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mlbi-lab) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mlbi-lab) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mlbi-lab) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mlbi-lab) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mlbi-lab) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mlbi-lab) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->mlbi-lab) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->mlbi-lab) (2026.2)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata->mlbi-lab) (1.15.0)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.12/dist-packages (from anndata->mlbi-lab) (3.16.0)
# Requirement already satisfied: legacy-api-wrap in /usr/local/lib/python3.12/dist-packages (from anndata->mlbi-lab) (1.5)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata->mlbi-lab) (8.4.0)
# Requirement already satisfied: scverse-misc>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from scverse-misc[settings]>=0.1.0->anndata->mlbi-lab) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.16 in /usr/local/lib/python3.12/dist-packages (from anndata->mlbi-lab) (4.16.0)
# Requirement already satisfied: zarr>=3.1 in /usr/local/lib/python3.12/dist-packages (from anndata->mlbi-lab) (3.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->mlbi-lab) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown->mlbi-lab) (3.29.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown->mlbi-lab) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown->mlbi-lab) (4.67.3)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.12/dist-packages (from lifelines->mlbi-lab) (1.8.0)
# Requirement already satisfied: autograd-gamma>=0.3 in /usr/local/lib/python3.12/dist-packages (from lifelines->mlbi-lab) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from lifelines->mlbi-lab) (1.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mlbi-lab) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mlbi-lab) (3.6.0)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines->mlbi-lab) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines->mlbi-lab) (2.22.1)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines->mlbi-lab) (2.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mlbi-lab) (1.17.0)
# Requirement already satisfied: session-info2 in /usr/local/lib/python3.12/dist-packages (from scverse-misc>=0.1.0->scverse-misc[settings]>=0.1.0->anndata->mlbi-lab) (0.4.1)
# Requirement already satisfied: pydantic-settings in /usr/local/lib/python3.12/dist-packages (from scverse-misc[settings]>=0.1.0->anndata->mlbi-lab) (2.14.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from scverse-misc[settings]>=0.1.0->anndata->mlbi-lab) (1.2.2)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr>=3.1->anndata->mlbi-lab) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr>=3.1->anndata->mlbi-lab) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr>=3.1->anndata->mlbi-lab) (0.16.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->mlbi-lab) (2.8.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->mlbi-lab) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->mlbi-lab) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->mlbi-lab) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->mlbi-lab) (2026.6.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->mlbi-lab) (1.7.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr>=3.1->anndata->mlbi-lab) (6.0.3)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings->scverse-misc[settings]>=0.1.0->anndata->mlbi-lab) (2.13.4)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings->scverse-misc[settings]>=0.1.0->anndata->mlbi-lab) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->pydantic-settings->scverse-misc[settings]>=0.1.0->anndata->mlbi-lab) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->pydantic-settings->scverse-misc[settings]>=0.1.0->anndata->mlbi-lab) (2.46.4)

# %%
# !pip list

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import pearsonr
from scipy.stats import ttest_ind, mannwhitneyu, f_oneway, kruskal

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn import cluster, mixture
from sklearn.neighbors import kneighbors_graph

from sknetwork.clustering import Louvain
from mlbi.datasets import load_data

# %%
load_data()
# Out:
# You can select one of:
#   cancerseek
#   ccle-ctrpv2
#   heart_failure
#   hotel_bookings
#   house_price
#   labor_force
#   metabric
#   scores
#   tcga-brca
#   time-series
#   time-series2

# %% [markdown]
# ## 1. Data Frame의 구조와 활용법 실습

# %% [markdown]
# ### 분석 관점에서 보는 DataFrame
#
# 생명과학/의학 데이터 분석에서는 대부분의 자료가 표 형태로 정리됩니다.
#
# - 행(row): 샘플, 환자, 세포주, 실험 조건
# - 열(column): 유전자, 단백질, 임상 변수, 약물 반응값
# - index: 각 행을 구분하는 이름 또는 ID
# - values: 실제 측정값
#
# 엑셀과 비슷해 보이지만, `pandas DataFrame`은 행/열 선택, 조건 필터링, 통계 요약, 시각화 연동을 코드로 재현할 수 있다는 점이 중요합니다.

# %%
# 아주 작은 예제 DataFrame을 먼저 만들어 봅니다.
# 실제 바이오 데이터도 구조는 이 예제와 같습니다.

example_df = pd.DataFrame({
    'sample_id': ['S1', 'S2', 'S3', 'S4'],
    'subtype': ['Lum.A', 'Lum.B', 'Basal', 'Her2'],
    'ESR1': [12.4, 8.1, 1.2, 4.5],
    'ERBB2': [3.1, 4.0, 2.8, 14.2],
    'MKI67': [2.3, 7.8, 9.1, 6.5]
})

example_df
# Out:
#   sample_id subtype  ESR1  ERBB2  MKI67
# 0        S1   Lum.A  12.4    3.1    2.3
# 1        S2   Lum.B   8.1    4.0    7.8
# 2        S3   Basal   1.2    2.8    9.1
# 3        S4    Her2   4.5   14.2    6.5

# %%
example_df.max(axis=0)
example_df[['ESR1', 'ERBB2']].std()
# Out:
# ESR1     4.811445
# ERBB2    5.473801
# dtype: float64

# %% [markdown]
# ### 빠른 복습: 한 열과 여러 열 선택
#
# `df['ESR1']`은 한 열을 `Series`로 가져오고, `df[['ESR1', 'ERBB2']]`는 여러 열을 `DataFrame`으로 가져옵니다.
# 대괄호가 하나인지 두 개인지에 따라 결과의 타입이 달라진다는 점을 자주 확인하세요.

# %%
california_housing_df

# %%
example_df.to_csv('example_df.csv')

# %%
print(type(example_df['ESR1']))
print(type(example_df[['ESR1', 'ERBB2']]))

example_df[['ESR1', 'ERBB2']]
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
#    ESR1  ERBB2
# 0  12.4    3.1
# 1   8.1    4.0
# 2   1.2    2.8
# 3   4.5   14.2

# %% [markdown]
# ### 빠른 복습: 조건으로 샘플 고르기
#
# 아래 예시는 `ESR1` 발현량이 높은 샘플만 고르는 코드입니다.
# 실제 분석에서는 특정 subtype, 특정 stage, 특정 발현량 기준에 맞는 샘플을 고를 때 같은 방식을 씁니다.

# %%
high_esr1 = example_df[example_df['ESR1'] > 5]
high_esr1

# %% [markdown]
# ### 데이터 불러오기 - CancerSEEK data

# %%
load_data()
# Out:
# You can select one of:
#   cancerseek
#   ccle-ctrpv2
#   heart_failure
#   hotel_bookings
#   house_price
#   labor_force
#   metabric
#   scores
#   tcga-brca
#   time-series
#   time-series2

# %%
data = load_data('cancerseek')
data.keys()
# Out:
# dict_keys(['protein_expression', 'clinical_info'])

# %%
df_pep = data['protein_expression']
df_clinical = data['clinical_info']
#환자의 39개 단백질 elisa 측정치 바이오 마커 값들
df_pep.head()
# Out:
#                     AFP  Angiopoietin-2      AXL  CA-125  CA 15-3  CA19-9  \
# Sample ID #
# CRC 455 PLS 1  1583.450         5598.50  3621.04   5.090    19.08  16.452
# CRC 456 PLS 1   715.308        20936.35  2772.96   7.270    10.04  40.910
# CRC 457 PLS 1  4365.530         2350.93  4120.77   4.854    16.96  16.452
# CRC 458 PLS 1   715.308         1604.34  2029.96   5.390     8.31  16.452
# CRC 459 PLS 1   801.300         2087.57  2069.17   4.854    11.73  16.452
#
#                 CD44     CEA  CYFRA 21-1  DKK1  ...  Prolactin    sEGFR  \
# Sample ID #                                     ...
# CRC 455 PLS 1   9.81   540.0    1938.654  0.78  ...   11606.60  3284.17
# CRC 456 PLS 1  27.57  5902.0    1938.654  0.77  ...   14374.99  1911.81
# CRC 457 PLS 1  14.59   974.0    1976.940  0.90  ...   38375.00  1743.94
# CRC 458 PLS 1   7.78  2028.0    1938.654  0.64  ...   12072.51  1059.24
# CRC 459 PLS 1  12.21   615.0    1938.654  0.78  ...   23718.17  1736.92
#
#                   sFas    SHBG  sHER2/sEGFR2/sErbB2  sPECAM-1     TGFa  \
# Sample ID #
# CRC 455 PLS 1  204.792   55.06              6832.07   9368.53   16.086
# CRC 456 PLS 1  204.792   72.92              5549.47   6224.55   16.086
# CRC 457 PLS 1  204.792  173.78              3698.16   4046.48  179.030
# CRC 458 PLS 1  204.792   29.47              5856.00   6121.93   16.086
# CRC 459 PLS 1  204.792   78.07              5447.93   6982.32   16.086
#
#                Thrombospondin-2    TIMP-1    TIMP-2
# Sample ID #
# CRC 455 PLS 1          21863.74  56428.71  39498.82
# CRC 456 PLS 1          29669.66  73940.49  41277.09
# CRC 457 PLS 1           6020.47  22797.28  28440.60
# CRC 458 PLS 1           4331.02  20441.19  25896.73
# CRC 459 PLS 1           2311.91  56288.51  49425.20
#
# [5 rows x 39 columns]

# %%
#데이터규격확인
df_pep.shape, df_clinical.shape
# Out:
# ((1803, 39), (1803, 11))

# %%
df_clinical['AJCC Stage'].value_counts()
#print(df_clinical['AJCC Stage'].isnull().sum()) # .sum()을 추가하여 결측값의 개수를 출력합니다.
# Out:
# 799

# %%
df_clinical['Tumor type'].value_counts()
# Out:
# Tumor type
# Normal        799
# Colorectum    388
# Breast        208
# Lung          104
# Pancreas       93
# Stomach        68
# Ovary          54
# Esophagus      45
# Liver          44
# Name: count, dtype: int64

# %%
df_clinical['Tumor type'].hist()

# %% [markdown]
# ### Understanding `np.log10` with `hist()`
#
# As explained, `CA19-9` is in `df_pep`. A common approach is to apply a logarithmic transformation to highly skewed data, like many protein expression values, to better visualize their distribution. Let's plot the histogram of the `CA19-9` values after applying a `log10` transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Check if 'CA19-9' column exists in df_pep and plot its log10 histogram
if 'CA19-9' in df_pep.columns:
    plt.figure(figsize=(8, 5))
    np.log10(df_pep['CA19-9']).hist(bins=50, edgecolor='black', log=True) # Added log=True
    plt.title('Histogram of log10(CA19-9) in df_pep')
    plt.xlabel('Log10[CA19-9]') # Updated xlabel as requested
    plt.ylabel('Frequency (log scale)') # Updated ylabel to reflect log scale
    plt.grid(axis='y', alpha=0.75)
    plt.show()
else:
    print("Error: 'CA19-9' column not found in df_pep.")

# %%
np.log10(df_pep['CA19-9']).hist(bins=50, edgecolor='black', log=True)
plt.xlabel('Log10[CA19-9]')
# Out:
# Text(0.5, 0, 'Log10[CA19-9]')

# %% [markdown]
# ### 다른 데이터셋 - TCGA BRCA gene expression and clinical data
#
# * 이미 오래된 데이터이기 때문에 다른 데이터셋 분석 후에 보조자료로 사용하면 좋음

# %%
data = load_data('tcga-brca')
data.keys()
# Out:
# Loading TCGA-BRCA data .. done
# dict_keys(['gene_expression', 'clinical_info'])

# %%
df_gep = data['gene_expression']
df_clinical = data['clinical_info']

# %%
df_gep.shape, df_clinical.shape
#1932개 샘플, mRNA 20531 유전자에 대한 발현량만 들어가 있음
#랜덤 샘플링이어서 노이즈가 있고 추정치라ㅡㄴ 사실을 기억해야함
#에티더가 100프로 정확하다고 생각하면 안됨 10%는 거짓말을 하고 있다고 생각해야함
# Out:
# ((1092, 20531), (1092, 32))

# %%
df_clinical.columns.values
# Out:
# array(['pid', 'age', 'gender', 'hist.type', 'menopause.status',
#        'surgical.proc', 'init.metastasis', 'patho.stage', 'M.Stage',
#        'N.Stage', 'T.Stage', 'Patho.Stage', 'er.status', 'pr.status',
#        'her2.status', 'PAM50.class', 'subtype', 'radiation.therapy',
#        'chemo.therapy', 'hormone.therapy', 'immuno.therapy',
#        'ancillary.therapy', 'target.mole.therapy', 'other.therapy',
#        'therapy', 'vital.status', 'days.to.event', 'cancer.status',
#        'days.to.date.of.last.contact', 'days.to.date.of.death',
#        'OS.event', 'OS.Time'], dtype=object)

# %%
np.1og10([])

# %%
df_clinical['init.metastasis'].value_counts()
# Out:
# init.metastasis
# no     381
# yes     12
# Name: count, dtype: int64

# %%
df_clinical.isnull().sum()
# Out:
# pid                               0
# age                               7
# gender                            7
# hist.type                         8
# menopause.status                 96
# surgical.proc                    63
# init.metastasis                 699
# patho.stage                      15
# M.Stage                           7
# N.Stage                           7
# T.Stage                           7
# Patho.Stage                      15
# er.status                        55
# pr.status                        56
# her2.status                     184
# PAM50.class                     579
# subtype                           0
# radiation.therapy                 0
# chemo.therapy                     0
# hormone.therapy                   0
# immuno.therapy                    0
# ancillary.therapy                 0
# target.mole.therapy               0
# other.therapy                     0
# therapy                           0
# vital.status                      7
# days.to.event                     7
# cancer.status                    72
# days.to.date.of.last.contact      7
# days.to.date.of.death           942
# OS.event                          7
# OS.Time                           7
# dtype: int64

# %%
df_clinical.head()
# Out:
#                                        pid   age  gender  \
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07  TCGA.AR.A251  51.0  female
# TCGA.BH.A1FR.01A.11R.A13Q.07  TCGA.BH.A1FR  73.0  female
# TCGA.BH.A8G0.01A.11R.A352.07  TCGA.BH.A8G0  54.0  female
# TCGA.A8.A096.01A.11R.A00Z.07  TCGA.A8.A096  73.0  female
# TCGA.A8.A09E.01A.11R.A00Z.07  TCGA.A8.A09E  73.0  female
#
#                                                    hist.type menopause.status  \
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07   infiltrating ductal carcinoma              pre
# TCGA.BH.A1FR.01A.11R.A13Q.07                  other, specify              NaN
# TCGA.BH.A8G0.01A.11R.A352.07  infiltrating lobular carcinoma             peri
# TCGA.A8.A096.01A.11R.A00Z.07   infiltrating ductal carcinoma             post
# TCGA.A8.A09E.01A.11R.A00Z.07   infiltrating ductal carcinoma             post
#
#                                   surgical.proc init.metastasis patho.stage  \
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07              other             NaN  stage iiia
# TCGA.BH.A1FR.01A.11R.A13Q.07              other             NaN  stage iiib
# TCGA.BH.A8G0.01A.11R.A352.07  simple mastectomy             NaN   stage iib
# TCGA.A8.A096.01A.11R.A00Z.07              other             NaN   stage iia
# TCGA.A8.A09E.01A.11R.A00Z.07              other             NaN  stage iiib
#
#                              M.Stage N.Stage  ... target.mole.therapy  \
# TCGA.barcode                                  ...
# TCGA.AR.A251.01A.12R.A169.07      M0      N2  ...                   0
# TCGA.BH.A1FR.01A.11R.A13Q.07      M0      N1  ...                   0
# TCGA.BH.A8G0.01A.11R.A352.07      M0      N1  ...                   0
# TCGA.A8.A096.01A.11R.A00Z.07      M0      N0  ...                   0
# TCGA.A8.A09E.01A.11R.A00Z.07      M0      N1  ...                   0
#
#                              other.therapy therapy vital.status days.to.event  \
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07             0    BOTH        alive        3030.0
# TCGA.BH.A1FR.01A.11R.A13Q.07             0      NO         dead        1642.0
# TCGA.BH.A8G0.01A.11R.A352.07             0      CO        alive         662.0
# TCGA.A8.A096.01A.11R.A00Z.07             0      NO        alive           0.0
# TCGA.A8.A09E.01A.11R.A00Z.07             0      HO        alive         943.0
#
#                              cancer.status days.to.date.of.last.contact  \
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07    tumor free                       1373.0
# TCGA.BH.A1FR.01A.11R.A13Q.07    with tumor                       1642.0
# TCGA.BH.A8G0.01A.11R.A352.07    tumor free                        662.0
# TCGA.A8.A096.01A.11R.A00Z.07    tumor free                          0.0
# TCGA.A8.A09E.01A.11R.A00Z.07    with tumor                        942.0
#
#                               days.to.date.of.death  OS.event  OS.Time
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07                    NaN       0.0   3030.0
# TCGA.BH.A1FR.01A.11R.A13Q.07                 1642.0       1.0   1642.0
# TCGA.BH.A8G0.01A.11R.A352.07                    NaN       0.0    662.0
# TCGA.A8.A096.01A.11R.A00Z.07                    NaN       0.0      0.0
# TCGA.A8.A09E.01A.11R.A00Z.07                    NaN       0.0    943.0
#
# [5 rows x 32 columns]

# %%
df_clinical.columns.values
# Out:
# array(['pid', 'age', 'gender', 'hist.type', 'menopause.status',
#        'surgical.proc', 'init.metastasis', 'patho.stage', 'M.Stage',
#        'N.Stage', 'T.Stage', 'Patho.Stage', 'er.status', 'pr.status',
#        'her2.status', 'PAM50.class', 'subtype', 'radiation.therapy',
#        'chemo.therapy', 'hormone.therapy', 'immuno.therapy',
#        'ancillary.therapy', 'target.mole.therapy', 'other.therapy',
#        'therapy', 'vital.status', 'days.to.event', 'cancer.status',
#        'days.to.date.of.last.contact', 'days.to.date.of.death',
#        'OS.event', 'OS.Time'], dtype=object)

# %%
df_gep.shape, df_clinical.shape

# %%
df_gep
# Out:
#                               100130426  100133144  100134869  10357  10431  \
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07        0.0        5.2        0.9    2.9   94.9
# TCGA.BH.A1FR.01A.11R.A13Q.07        0.0        0.4        0.1    2.8   42.0
# TCGA.BH.A8G0.01A.11R.A352.07        0.0        0.4        0.9    3.8   32.5
# TCGA.A8.A096.01A.11R.A00Z.07        0.0        0.1        0.2    4.8   36.3
# TCGA.A8.A09E.01A.11R.A00Z.07        0.0        0.2        0.4    4.2   37.0
# ...                                 ...        ...        ...    ...    ...
# TCGA.BH.A0B0.01A.21R.A115.07        0.0        0.2        0.2    5.5   62.3
# TCGA.UU.A93S.01A.21R.A41B.07        0.0        0.2        0.5    6.7  141.7
# TCGA.BH.AB28.01A.31R.A41B.07        0.0        0.6        0.9    5.4   32.5
# TCGA.A2.A0T3.01A.21R.A115.07        0.0        0.4        0.4    6.6   40.4
# TCGA.PL.A8LV.01A.21R.A41B.07        0.0        1.0        1.7    3.6   48.2
#
#                               136542  155060  26823  280660  317712  ...  \
# TCGA.barcode                                                         ...
# TCGA.AR.A251.01A.12R.A169.07     0.0     7.1    0.1     0.0     0.0  ...
# TCGA.BH.A1FR.01A.11R.A13Q.07     0.0    12.9    0.0     0.0     0.0  ...
# TCGA.BH.A8G0.01A.11R.A352.07     0.0    22.3    0.0     0.0     0.0  ...
# TCGA.A8.A096.01A.11R.A00Z.07     0.0     2.8    0.0     0.0     0.0  ...
# TCGA.A8.A09E.01A.11R.A00Z.07     0.0    21.8    0.0     0.0     0.0  ...
# ...                              ...     ...    ...     ...     ...  ...
# TCGA.BH.A0B0.01A.21R.A115.07     0.0     4.9    0.0     0.0     0.0  ...
# TCGA.UU.A93S.01A.21R.A41B.07     0.0     9.0    0.0     0.0     0.0  ...
# TCGA.BH.AB28.01A.31R.A41B.07     0.0    17.6    0.1     0.0     0.0  ...
# TCGA.A2.A0T3.01A.21R.A115.07     0.0    19.5    0.0     0.0     0.0  ...
# TCGA.PL.A8LV.01A.21R.A41B.07     0.0    27.3    0.0     0.0     0.0  ...
#
#                               ZXDA   ZXDB  ZXDC  ZYG11A  ZYG11B    ZYX  ZZEF1  \
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07   2.3   24.8  77.4    17.9    81.1  153.3  140.6
# TCGA.BH.A1FR.01A.11R.A13Q.07   4.9   53.2  66.4     3.5    58.0  128.0   87.3
# TCGA.BH.A8G0.01A.11R.A352.07   3.4   22.8  54.0     6.2    37.2  258.8  100.6
# TCGA.A8.A096.01A.11R.A00Z.07   4.0   23.9  56.2     0.2    41.7  167.7   80.4
# TCGA.A8.A09E.01A.11R.A00Z.07   3.9   27.9  70.6     1.8    38.1  121.8   70.9
# ...                            ...    ...   ...     ...     ...    ...    ...
# TCGA.BH.A0B0.01A.21R.A115.07   3.9   22.2  47.4     3.1    31.2  193.5   48.8
# TCGA.UU.A93S.01A.21R.A41B.07   1.0    9.9  44.6     0.6    27.5  274.7   26.4
# TCGA.BH.AB28.01A.31R.A41B.07   4.8   43.2  68.8     1.6    47.3  226.5  123.1
# TCGA.A2.A0T3.01A.21R.A115.07   3.8  150.9  54.0    10.9    52.8   96.9   79.2
# TCGA.PL.A8LV.01A.21R.A41B.07   1.4   15.1  74.6    11.0    34.6  209.4   47.0
#
#                               ZZZ3  psiTPTE22  tAKR
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07  99.2       23.6   0.0
# TCGA.BH.A1FR.01A.11R.A13Q.07  95.3       12.3   0.0
# TCGA.BH.A8G0.01A.11R.A352.07  49.3       24.5   0.0
# TCGA.A8.A096.01A.11R.A00Z.07  60.4        1.3   0.0
# TCGA.A8.A09E.01A.11R.A00Z.07  22.3        1.2   0.0
# ...                            ...        ...   ...
# TCGA.BH.A0B0.01A.21R.A115.07  41.2        3.6   0.0
# TCGA.UU.A93S.01A.21R.A41B.07  19.0        0.4   0.0
# TCGA.BH.AB28.01A.31R.A41B.07  37.8        3.9   0.0
# TCGA.A2.A0T3.01A.21R.A115.07  44.1        1.8   0.0
# TCGA.PL.A8LV.01A.21R.A41B.07  30.6       18.6   0.0
#
# [1092 rows x 20531 columns]

# %%
df_gep.sum(axis = 1)
# Out:
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07    999975.8
# TCGA.BH.A1FR.01A.11R.A13Q.07    999951.2
# TCGA.BH.A8G0.01A.11R.A352.07    999973.1
# TCGA.A8.A096.01A.11R.A00Z.07    999975.8
# TCGA.A8.A09E.01A.11R.A00Z.07    999984.9
#                                   ...
# TCGA.BH.A0B0.01A.21R.A115.07    999990.5
# TCGA.UU.A93S.01A.21R.A41B.07    999974.4
# TCGA.BH.AB28.01A.31R.A41B.07    999976.7
# TCGA.A2.A0T3.01A.21R.A115.07    999983.7
# TCGA.PL.A8LV.01A.21R.A41B.07    999977.9
# Length: 1092, dtype: float64

# %%
b = df_gep['ESR1'] >= 10
#true인 애들만 (10보다 크거나 같은 애들만)
df_gep.loc[b].shape
# Out:
# (904, 20531)

# %%
#sorting, esr1을 오름차순으로 sorting - ascending=True
df_gep.sort_values(by='ESR1')
# Out:
#                               100130426  100133144  100134869  10357  10431  \
# TCGA.barcode
# TCGA.E2.A158.01A.11R.A12D.07        0.0        2.9        2.2    3.6   56.7
# TCGA.AQ.A54N.01A.11R.A266.07        0.0        0.0        0.3    7.4  141.3
# TCGA.A2.A3XV.01A.21R.A239.07        0.0        0.0        0.2    3.5   94.2
# TCGA.A2.A0D0.01A.11R.A00Z.07        0.0        0.1        0.1   11.5   65.6
# TCGA.A2.A04U.01A.11R.A115.07        0.0        0.0        0.0   20.5  218.4
# ...                                 ...        ...        ...    ...    ...
# TCGA.E9.A1R7.01A.11R.A14M.07        0.0        0.6        0.3    5.6   62.4
# TCGA.AQ.A1H2.01A.11R.A13Q.07        0.0        0.4        0.2    1.9   54.5
# TCGA.D8.A1XC.01A.11R.A14D.07        0.0        0.2        0.3    2.7   28.6
# TCGA.C8.A1HE.01A.11R.A13Q.07        0.0        0.4        0.2    4.8   49.6
# TCGA.C8.A26Z.01A.11R.A16F.07        0.0        1.2        0.3    5.1   59.4
#
#                               136542  155060  26823  280660  317712  ...  \
# TCGA.barcode                                                         ...
# TCGA.E2.A158.01A.11R.A12D.07     0.0    24.9    0.1     0.0     0.0  ...
# TCGA.AQ.A54N.01A.11R.A266.07     0.0    28.1    0.0     0.0     0.0  ...
# TCGA.A2.A3XV.01A.21R.A239.07     0.0    11.8    0.0     0.0     0.0  ...
# TCGA.A2.A0D0.01A.11R.A00Z.07     0.0     5.8    0.0     0.0     0.0  ...
# TCGA.A2.A04U.01A.11R.A115.07     0.0     3.9    0.0     0.0     0.0  ...
# ...                              ...     ...    ...     ...     ...  ...
# TCGA.E9.A1R7.01A.11R.A14M.07     0.0     7.3    0.1     0.0     0.0  ...
# TCGA.AQ.A1H2.01A.11R.A13Q.07     0.0     5.2    0.1     0.0     0.0  ...
# TCGA.D8.A1XC.01A.11R.A14D.07     0.0     5.8    0.1     0.0     0.0  ...
# TCGA.C8.A1HE.01A.11R.A13Q.07     0.0     9.4    0.0     0.0     0.0  ...
# TCGA.C8.A26Z.01A.11R.A16F.07     0.0    10.6    0.0     0.0     0.0  ...
#
#                               ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B    ZYX  ZZEF1  \
# TCGA.barcode
# TCGA.E2.A158.01A.11R.A12D.07   3.2  31.8  90.2    19.0    44.3  384.1   40.6
# TCGA.AQ.A54N.01A.11R.A266.07   1.0  10.2  72.1    10.1    26.0  407.2   55.5
# TCGA.A2.A3XV.01A.21R.A239.07   0.3   7.8  23.2    11.1    16.3  246.8   16.0
# TCGA.A2.A0D0.01A.11R.A00Z.07   0.9  11.9  81.0    15.2    48.6  411.5   25.1
# TCGA.A2.A04U.01A.11R.A115.07   0.9   8.7  43.6     6.5    29.3  160.4   30.7
# ...                            ...   ...   ...     ...     ...    ...    ...
# TCGA.E9.A1R7.01A.11R.A14M.07   4.5  45.6  69.2    33.2   110.0   48.1   51.1
# TCGA.AQ.A1H2.01A.11R.A13Q.07   4.3  37.3  57.3     3.7    61.2   73.1   65.9
# TCGA.D8.A1XC.01A.11R.A14D.07   6.2  51.5  75.6     1.5    51.2  102.5  111.1
# TCGA.C8.A1HE.01A.11R.A13Q.07   4.6  35.2  69.7     4.6    59.9  106.9   87.0
# TCGA.C8.A26Z.01A.11R.A16F.07   5.1  88.0  70.9     7.1    38.6  113.3  150.1
#
#                                ZZZ3  psiTPTE22  tAKR
# TCGA.barcode
# TCGA.E2.A158.01A.11R.A12D.07   94.3       53.4   0.0
# TCGA.AQ.A54N.01A.11R.A266.07   30.3       17.3   0.0
# TCGA.A2.A3XV.01A.21R.A239.07   15.3        0.6   0.0
# TCGA.A2.A0D0.01A.11R.A00Z.07   46.6        0.2   0.0
# TCGA.A2.A04U.01A.11R.A115.07   62.9        4.3   0.0
# ...                             ...        ...   ...
# TCGA.E9.A1R7.01A.11R.A14M.07   61.9        0.5   0.0
# TCGA.AQ.A1H2.01A.11R.A13Q.07   42.2        0.4   0.0
# TCGA.D8.A1XC.01A.11R.A14D.07  106.9        0.4   0.0
# TCGA.C8.A1HE.01A.11R.A13Q.07   86.1        0.7   0.0
# TCGA.C8.A26Z.01A.11R.A16F.07   36.7        0.6   0.0
#
# [1092 rows x 20531 columns]

# %% [markdown]
# ### DataFrame 활용 연습
# 1. head() method를 이용한 Data frame 확인: head(), tail()
# 2. shape attribute를 이용한 size 확인: shape
# 3. row name(index) 및 column name 확인
# 4. index/column name을 이용한 행/열 가져오기: loc(), iloc()
# 5. pandas series
# 6. NA(None)이 포함된 element 확인하기: isnull()
# 7. 행/열의 합/평균/표준편차 구하기: sum(), mean(), std()
# 8. 행/열의 최대값/최소값/최대값의 index 구하기: max(), min(), idxmax(), idxmin()
# 9. 범주형 데이터의 범주 카운트 구하기: value_counts()
# 10. 조건에 맞는 행들만 선택하기 - boolean indexing
# 11. 범주형 데이터가 특정 집합의 원소인지 아닌지 조사하기: isin()
# 12. 등호/부등호의 사용: ==, >, <
# 13. 특정 열 기준으로 정렬하기: sort_values()

# %%
# TCGA-BRCA gene expression table과 clinical table을 이용해 DataFrame 기본기를 연습합니다.

print('gene expression shape:', df_gep.shape)
print('clinical info shape:', df_clinical.shape)

# 1) 앞/뒤 일부 행 확인
print('--- df_gep head ---')
display(df_gep.head())

print('--- df_clinical head ---')
display(df_clinical.head())

# %% [markdown]
# ### DataFrame 핵심 조작 예제
#
# 아래 셀들은 실제 분석에서 거의 매번 쓰는 조작입니다.
# 처음에는 코드를 외우기보다, “행을 고르는지, 열을 고르는지, 조건을 거는지”를 구분해서 읽는 것이 중요합니다.

# %%
# 열 이름 확인
print(df_gep.columns[:10])
print(df_clinical.columns)

# 관심 유전자 3개만 선택
marker_genes = ['ESR1', 'ERBB2', 'MKI67']
df_marker = df_gep[marker_genes]

df_marker.head()

# %%
# loc: index/column 이름으로 선택
# iloc: 행/열 번호 위치로 선택

print('첫 번째 샘플 ID:', df_gep.index[0])

display(df_gep.loc[df_gep.index[0], marker_genes])
display(df_gep.iloc[:5, :5])

# %%
# 임상 정보에서 subtype별 샘플 수 확인
# value_counts()는 범주형 변수의 분포를 볼 때 자주 사용합니다.

df_clinical['subtype'].value_counts(dropna=False)

# %%
# gene expression과 clinical subtype을 하나의 DataFrame으로 합치기
# 두 table의 index가 같은 sample ID라고 가정하고 열 방향(axis=1)으로 붙입니다.

practice_df = pd.concat([
    df_gep[marker_genes],
    df_clinical[['subtype']]
], axis=1)

practice_df.head()

# %%
# 조건 필터링: Basal-like 샘플만 선택
basal_df = practice_df[practice_df['subtype'] == 'Basal']

print(basal_df.shape)
basal_df.head()

# %%
# groupby: subtype별 marker gene 평균과 표준편차 계산
summary_mean = practice_df.groupby('subtype')[marker_genes].mean()
summary_std = practice_df.groupby('subtype')[marker_genes].std()

print('Subtype별 평균')
display(summary_mean)

print('Subtype별 표준편차')
display(summary_std)

# %% [markdown]
# ### 다른 데이터셋 - CCLE cellline gene expression and drug response measurement

# %%
data = load_data('ccle-ctrpv2')
data.keys()

# %%
df_gexp = data['gene_expression']
df_cl_info = data['cellline_info']
df_auc = data['auc']
df_ec50 = data['ec50']
df_drug_info = data['drug_info']

# %% [markdown]
# ### Homework
#
# 유방암은 크게 3가지의 subtype (Basal-like, Luminal 및 Her2)으로 구분한다. 또한, Lum.subtype은 다시 liminal A와 Luminal B로 나뉜다. 이들 subtype들은 대체로 3가지 유전자(ESR1, ERBB2, MKI67)의 발현량에 따라 구분되기도 한다. 3가지의 subtype (Basal-like, Luminal 및 Her2) 각각에 대해 3가지 유전자 (ESR1, ERBB2, MKI67)의 발현량의 평균과 표준편자를 각각 구하여 data frame으로 요약해 보아라. 이 때 data frame의 index는 subtype의 이름, columns는 유전자 이름으로 설정하라. (예, 'ESR1 (mean)', 'ESR1 (stdev)' 등) 이를 위해 필요한 정보는 TCGA-BRCA 데이터에 모두 포함되어 있으며 해당 데이터를 잘 살펴보고 필요 시 다음의 인터넷 사이트를 참고하라. NA가 포함된 부분은 적절히 제외하라.
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %% [markdown]
# #### Homework 접근 힌트
#
# 1. `df_gep[['ESR1', 'ERBB2', 'MKI67']]`로 관심 유전자만 고릅니다.
# 2. `df_clinical[['subtype']]`을 함께 붙여 분석용 DataFrame을 만듭니다.
# 3. `dropna()`로 subtype 또는 발현량 결측치를 정리합니다.
# 4. `groupby('subtype')` 뒤에 `mean()`과 `std()`를 적용합니다.
# 5. 결과를 보기 좋은 하나의 DataFrame으로 정리합니다.

# %%
# Homework template
# 아래 빈칸을 채워 subtype별 ESR1/ERBB2/MKI67 평균과 표준편차를 계산해 보세요.

marker_genes = ['ESR1', 'ERBB2', 'MKI67']

hw_df = pd.concat([
    df_gep[marker_genes],
    df_clinical[['subtype']]
], axis=1)

hw_df = hw_df.dropna(subset=marker_genes + ['subtype'])

# subtype_summary = ...
# subtype_summary

# %% [markdown]
# ## 2. 데이터 분포의 시각화 연습
#
# 시각화는 “분석 결과를 예쁘게 보여주는 단계”라기보다, 데이터가 어떤 모양인지 먼저 확인하는 탐색 과정입니다.
# 특히 바이오 데이터에서는 극단값, subtype별 차이, marker gene 간 관계를 눈으로 확인하는 과정이 중요합니다.
#
# 1. Histogram: 한 변수의 전체 분포
# 2. Pairplot: 여러 변수 간 관계
# 3. Box plot: 그룹별 분포 비교
# 4. Violin plot: 그룹별 분포 모양 비교
# 5. Heatmap / clustermap: 여러 유전자 패턴 비교

# %%
data = load_data('tcga-brca')

df_gep = data['gene_expression']
df_clinical = data['clinical_info']
# Out:
# Loading TCGA-BRCA data .. done

# %%
#원래 지수분포에 가깝기 때문에 좀 더 정규분포에 가깝게 만들기 위해서 log 변환을 시켜주는 것
#df_gep['ESR1'].hist(bins=50)
df_log_gep = np.log10(df_gep + 1)

# %%
df_log_gep['ESR1'].hist(bins=50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2031/3541124350.py in <cell line: 0>()
# ----> 1 df_log_gep.hist(bins=50)
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     249     """
#     250     plot_backend = _get_plot_backend(backend)
# --> 251     return plot_backend.hist_frame(
#     252         data,
#     253         column=column,
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     551         )
#     552
# --> 553     fig, axes = create_subplots(
#     554         naxes=naxes,
#     555         ax=ax,
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/tools.py in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     300             kwds["sharex"] = None
#     301             kwds["sharey"] = None
# --> 302         ax = fig.add_subplot(nrows, ncols, i + 1, **kwds)
#     303         axarr[i] = ax
#     304
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     766                 args = tuple(map(int, str(args[0])))
#     767             projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 768             ax = projection_class(self, *args, **pkw)
#     769             key = (projection_class, pkw)
#     770         return self._add_axes_internal(ax, key)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in __init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     694
#     695         self._rasterization_zorder = None
# --> 696         self.clear()
#     697
#     698         # funcs used to format x and y - fall back on major formatters
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in clear(self)
#    1414             self.cla()
#    1415         else:
# -> 1416             self.__clear()
#    1417
#    1418     def cla(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in __clear(self)
#    1330         self.containers = []
#    1331
# -> 1332         self.grid(False)  # Disable grid on init to use rcParameter
#    1333         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1334                   axis=mpl.rcParams['axes.grid.axis'])
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in grid(self, visible, which, axis, **kwargs)
#    3310         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3311         if axis in ['x', 'both']:
# -> 3312             self.xaxis.grid(visible, which=which, **kwargs)
#    3313         if axis in ['y', 'both']:
#    3314             self.yaxis.grid(visible, which=which, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in grid(self, visible, which, **kwargs)
#    1744             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1745                                 if visible is None else visible)
# -> 1746             self.set_tick_params(which='major', **gridkw)
#    1747         self.stale = True
#    1748
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kwargs)
#     984             if which in ['major', 'both']:
#     985                 self._major_tick_kw.update(kwtrans)
# --> 986                 for tick in self.majorTicks:
#     987                     tick._apply_params(**kwtrans)
#     988             if which in ['minor', 'both']:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in __get__(self, instance, owner)
#     545             if self._major:
#     546                 instance.majorTicks = []
# --> 547                 tick = instance._get_tick(major=True)
#     548                 instance.majorTicks = [tick]
#     549                 return instance.majorTicks
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in _get_tick(self, major)
#    1601                 "_tick_class or reimplement _get_tick()")
#    1602         tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1603         return self._tick_class(self.axes, 0, major=major, **tick_kw)
#    1604
#    1605     def _get_tick_label_size(self, axis_name):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     366
#     367     def __init__(self, *args, **kwargs):
# --> 368         super().__init__(*args, **kwargs)
#     369         # x in data coords, y in axes coords
#     370         ax = self.axes
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in __init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, labelfontfamily, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     168             **grid_kw,
#     169         )
# --> 170         self.gridline.get_path()._interpolation_steps = \
#     171             GRIDLINE_INTERPOLATION_STEPS
#     172         self.label1 = mtext.Text(
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/lines.py in get_path(self)
#    1036         """Return the `~matplotlib.path.Path` associated with this line."""
#    1037         if self._invalidy or self._invalidx:
# -> 1038             self.recache()
#    1039         return self._path
#    1040
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/lines.py in recache(self, always)
#     709             interpolation_steps = 1
#     710         xy = STEP_LOOKUP_MAP[self._drawstyle](*self._xy.T)
# --> 711         self._path = Path(np.asarray(xy).T,
#     712                           _interpolation_steps=interpolation_steps)
#     713         self._transformed_path = None
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     128         """
#     129         vertices = _to_unmasked_float_array(vertices)
# --> 130         _api.check_shape((None, 2), vertices=vertices)
#     131
#     132         if codes is not None and len(vertices):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/__init__.py in check_shape(shape, **kwargs)
#     151
#     152         if (len(data_shape) != len(shape)
# --> 153                 or any(s != t and t is not None for s, t in zip(data_shape, shape))):
#     154             dim_labels = iter(itertools.chain(
#     155                 'NMLKJIH',
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/__init__.py in <genexpr>(.0)
#     151
#     152         if (len(data_shape) != len(shape)
# --> 153                 or any(s != t and t is not None for s, t in zip(data_shape, shape))):
#     154             dim_labels = iter(itertools.chain(
#     155                 'NMLKJIH',
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x7fec2a380040> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#     280
#     281
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     129         for manager in cls.get_all_fig_managers():
#     130             if force or manager.canvas.figure.stale:
# --> 131                 manager.canvas.draw_idle()
#     132
#     133
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1889         if not self._is_idle_drawing:
#    1890             with self._idle_draw_cntx():
# -> 1891                 self.draw(*args, **kwargs)
#    1892
#    1893     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     380         with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381               else nullcontext()):
# --> 382             self.figure.draw(self.renderer)
#     383             # A GUI class may be need to update a window using this draw, so
#     384             # don't forget to call the superclass.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3179             _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
#    3180
# -> 3181         mimage._draw_list_compositing_images(
#    3182             renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3183
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in draw(self, renderer)
#    1417
#    1418         for tick in ticks_to_draw:
# -> 1419             tick.draw(renderer)
#    1420
#    1421         # Shift label away from axes to avoid overlapping ticklabels.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in draw(self, renderer)
#     274         for artist in [self.gridline, self.tick1line, self.tick2line,
#     275                        self.label1, self.label2]:
# --> 276             artist.draw(renderer)
#     277         renderer.close_group(self.__name__)
#     278         self.stale = False
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/text.py in draw(self, renderer)
#     777
#     778             gc = renderer.new_gc()
# --> 779             gc.set_foreground(self.get_color())
#     780             gc.set_alpha(self.get_alpha())
#     781             gc.set_url(self._url)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in set_foreground(self, fg, isRGBA)
#     899             self._rgb = fg
#     900         else:
# --> 901             self._rgb = colors.to_rgba(fg)
#     902
#     903     @_docstring.interpd
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     305             c = c[0]
#     306     # Special-case nth color syntax because it should not be cached.
# --> 307     if _is_nth_color(c):
#     308         prop_cycler = mpl.rcParams['axes.prop_cycle']
#     309         colors = prop_cycler.by_key().get('color', ['k'])
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _is_nth_color(c)
#     218 def _is_nth_color(c):
#     219     """Return whether *c* can be interpreted as an item in the color cycle."""
# --> 220     return isinstance(c, str) and _nth_color_re.match(c)
#     221
#     222
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7fec2a311580> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure),
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2156             if bbox_inches:
#    2157                 if bbox_inches == "tight":
# -> 2158                     bbox_inches = self.figure.get_tightbbox(
#    2159                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2160                     if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1846                 # need this conditional....
#    1847                 try:
# -> 1848                     bbox = ax.get_tightbbox(
#    1849                         renderer, bbox_extra_artists=bbox_extra_artists)
#    1850                 except TypeError:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4540
#    4541         for a in bbox_artists:
# -> 4542             bbox = a.get_tightbbox(renderer)
#    4543             if (bbox is not None
#    4544                     and 0 < bbox.width < np.inf
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     362             Returns None if clipping results in no intersection.
#     363         """
# --> 364         bbox = self.get_window_extent(renderer)
#     365         if self.get_clip_on():
#     366             clip_box = self.get_clip_box()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/spines.py in get_window_extent(self, renderer)
#     156             return bb
#     157         bboxes = [bb]
# --> 158         drawn_ticks = self.axis._update_ticks()
#     159
#     160         major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1291         """
#    1292         major_locs = self.get_majorticklocs()
# -> 1293         major_labels = self.major.formatter.format_ticks(major_locs)
#    1294         major_ticks = self.get_major_ticks(len(major_locs))
#    1295         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/ticker.py in format_ticks(self, values)
#     214     def format_ticks(self, values):
#     215         """Return the tick labels for all the ticks at once."""
# --> 216         self.set_locs(values)
#     217         return [self(value, i) for i, value in enumerate(values)]
#     218
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/ticker.py in set_locs(self, locs)
#     740                 self._compute_offset()
#     741             self._set_order_of_magnitude()
# --> 742             self._set_format()
#     743
#     744     def _compute_offset(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/ticker.py in _set_format(self)
#     839         thresh = 1e-3 * 10 ** loc_range_oom
#     840         while sigfigs >= 0:
# --> 841             if np.abs(locs - np.round(locs, decimals=sigfigs)).max() < thresh:
#     842                 sigfigs -= 1
#     843             else:
#
# KeyboardInterrupt:

# %%
#esr1의 분포를 보고 발현량보다 작으면 negative

# %%
df_log_gep['ESR1'].hist(bins = 40, alpha = 0.5)
df_log_gep['ERBB2'].hist(bins = 40, alpha = 0.5)

plt.xlabel('log(TPM)', fontsize = 12)
plt.ylabel('N samples', fontsize = 12)
plt.legend(['ESR1', 'ERBB2'])
plt.title('Gene expression of ESR1 and ERBB2')

# %% [markdown]
# #### pair wise scatter plot 그리기
# * 특징이 너무 많으면 좀 그래서 몇개를 골라서 그림

# %%
df = df_log_gep[['ESR1', 'ERBB2', 'MKI67']].copy(deep = True)
df['subtype'] = df_clinical['subtype'].copy(deep=True) #유방암 subtupe(범주형)을 붙이기
df
# Out:
#                                   ESR1     ERBB2     MKI67 subtype
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07  1.320146  2.166430  2.651375   Basal
# TCGA.BH.A1FR.01A.11R.A13Q.07  3.412712  2.401228  1.666518   Lum.A
# TCGA.BH.A8G0.01A.11R.A352.07  2.466868  2.672098  1.127105   Lum.A
# TCGA.A8.A096.01A.11R.A00Z.07  2.899821  2.492621  2.168792   Lum.A
# TCGA.A8.A09E.01A.11R.A00Z.07  3.065356  2.880070  1.899273   Lum.B
# ...                                ...       ...       ...     ...
# TCGA.BH.A0B0.01A.21R.A115.07  2.474508  2.284431  1.685742   Lum.A
# TCGA.UU.A93S.01A.21R.A41B.07  0.707570  4.271707  1.973128    Her2
# TCGA.BH.AB28.01A.31R.A41B.07  2.963079  2.997648  1.830589   Lum.A
# TCGA.A2.A0T3.01A.21R.A115.07  2.851014  2.548389  2.234011   Lum.B
# TCGA.PL.A8LV.01A.21R.A41B.07  0.707570  2.284205  2.226342   Basal
#
# [1092 rows x 4 columns]

# %%
df['subtype'].value_counts()
# Out:
# subtype
# Lum.A    622
# Basal    196
# Lum.B    187
# Her2      87
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                   ESR1     ERBB2     MKI67 subtype
# TCGA.barcode
# TCGA.AR.A251.01A.12R.A169.07  1.320146  2.166430  2.651375   Basal
# TCGA.BH.A1FR.01A.11R.A13Q.07  3.412712  2.401228  1.666518   Lum.A
# TCGA.BH.A8G0.01A.11R.A352.07  2.466868  2.672098  1.127105   Lum.A
# TCGA.A8.A096.01A.11R.A00Z.07  2.899821  2.492621  2.168792   Lum.A
# TCGA.A8.A09E.01A.11R.A00Z.07  3.065356  2.880070  1.899273   Lum.B

# %%
df['subtype'].value_counts()
# Out:
# subtype
# Lum.A    622
# Basal    196
# Lum.B    187
# Her2      87
# Name: count, dtype: int64

# %% [markdown]
# #### Pairplot 해석 포인트
#
# 각 점은 한 환자 샘플이고, 색은 유방암 subtype입니다.
# `ESR1`, `ERBB2`, `MKI67` 세 유전자만으로도 일부 subtype이 서로 다른 위치에 모이는지 관찰해 봅니다.

# %%
## Pairplot with hue
sns.pairplot(df, hue = 'subtype', diag_kind = 'kde')

# %% [markdown]
# #### Box plot 그리기
# * 그룹간의 분포의 차이를 조금 더 정량화 해서 보는것
# * 가운데서 median 값
# * Q1
# * 하위 25%
# * 상위 75%
# * 이 범위를 벗어난 값들 outlier - 점으로 찍어서 나타냄

# %%
sns.boxplot(data = df.iloc[:,:3])
# Out:
# <Axes: >

# %%
#ERbBB2만 선택, 각각의 유방암 subtype의 ERBB2 분포를 확인
#분포가 서로 비슷하면 의미가 았는데 그렇지 않으면 ㄴㄴ
sns.boxplot(data = df, y = 'ERBB2', x = 'subtype', hue = 'subtype')
# Out:
# <Axes: xlabel='subtype', ylabel='ERBB2'>

# %% [markdown]
# #### Violin plot 그리기

# %%
sns.violinplot(data = df, y = 'ERBB2', x = 'subtype', hue = 'subtype') #기본 설정 bw=1 -> 이걸 0.2로 줄이면 덜 스무스하게 나와서 자글자글함이 좀 더 보임
#HER2는 정규분포의 형태를 따르지 않는 것을 확인하고 두 그룹으로 또 나눌 수 있겠다는 것을 생각해볼 수 있다.
#다른 subtype들은 정규분포를 따른다.
# Out:
# <Axes: xlabel='subtype', ylabel='ERBB2'>

# %% [markdown]
# #### Heatmap 그리기
# * matrix를 한 눈에 볼 수 있도록 그리는 방법
#
# #### Clustering
# * 유사도를 따져서 계층적으로 클러스터 하는 것

# %%
#유전자를 다 보기엔 너무 많아서 50개만 뽑음
PAM50_genes = ['ACTR3B', 'ANLN', 'BAG1', 'BCL2', 'BIRC5', 'BLVRA',
 'CCNB1', 'CCNE1', 'CDC20', 'CDC6', 'CDH3', 'CENPF', 'CEP55',
 'CXXC5', 'EGFR', 'ERBB2', 'ESR1', 'EXO1', 'FGFR4', 'FOXA1',
 'FOXC1', 'GPR160', 'GRB7', 'KIF2C', 'KRT14', 'KRT17', 'KRT5',
 'MAPT', 'MDM2', 'MELK', 'MIA', 'MKI67', 'MLPH', 'MMP11', 'MYBL2',
 'MYC', 'NAT1', 'NDC80', 'NUF2', 'ORC6L', 'PGR', 'PHGDH', 'PTTG1',
 'RRM2', 'SFRP1', 'SLC39A6', 'TMEM45B', 'TYMS', 'UBE2C', 'UBE2T']

PAM50_genes = list(set(PAM50_genes).intersection(df_log_gep.columns.values))
len(PAM50_genes)
# Out:
# 50

# %%
#x유전자, 발현량
#맨 위 색깔 바는 암의 subtype
#subtype 별로 유전자에 따라 발현 패턴을 보는 것
#rna-seq gene expression 볼 때 자주 사용
#통계검정 박스플롯 많이 사용

X_sel = df_log_gep[PAM50_genes] # .copy(deep=True)
# X_sel = df_log_gep[['ESR1', 'ERBB2', 'MKI67']]
y = df_clinical['subtype']

plt.figure(num=None, figsize=(12, 5), dpi=80, facecolor='w', edgecolor='k')
# ax = sb.heatmap(X_sel.transpose())

lut = dict(zip(set(y), "rbgym"))
col_colors = y.map(lut)
dfc = pd.DataFrame([col_colors]).transpose()

g = sns.clustermap(X_sel.transpose(), col_cluster = True, row_cluster = True, standard_scale = 0,
                   col_colors = dfc, cmap="mako", figsize = (12,8))
g.fig.suptitle('Heatmap\n ', fontsize=20, va = 'center')

# Draw the legend bar for the classes
for label in list(set(y)):
    g.ax_col_dendrogram.bar(0, 0, color=lut[label],
                            label=label, linewidth=0)
g.ax_col_dendrogram.legend(loc="center right", bbox_to_anchor=(1.25, 0.5), ncol=1)
# ax.cax.set_position([.2, .2, .03, 1])
g.ax_heatmap.set_xlabel('Sample')
g.ax_heatmap.set_ylabel('Gene')
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# Text(1163.6527777777778, 0.5, 'Gene')

# %% [markdown]
# ### Homework
#
# 유방암은 크게 3가지의 subtype (Basal-like, Luminal 및 HER2-enriched)으로 구분한다. 또한, Luminal subtype은 다시 liminal A와 Luminal B로 나뉜다. 이들 subtype들은 대체로 3가지 유전자(ESR1, ERBB2, MKI67)의 발현량에 따라 구분되기도 한다.
#
# 1. 3가지의 subtype (Basal-like, Luminal 및 HER2-enriched) 각각에 대해 3가지 유전자 (ESR1, ERBB2, MKI67)의 발현량를 Violin plot으로 그려서 비교해 보아라. NA가 포함된 부분은 적절히 제외하라.
# 2. 3가지의 subtype (Basal-like, Luminal 및 HER2-enriched) 각각에 대해 3가지 유전자 (ESR1, ERBB2, MKI67)의 발현량를 Cluster Map으로 그려서 비교해 보아라.
# 3. 1/2의 비교 굘과에 대한 간략한 고찰을 제시하여라.
